# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOIHYUNJUN10/10720/blob/main/20260908.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
red = 1000
yellow = 2000
blue = 3000
green = 4000
redcount=int(input('빨간색 접시의 개수를 입력하세요:'))
yellowcount=int(input('노랑색 접시의 개수를 입력하세요:'))
bluecount=int(input('파란색 접시의 개수를 입력하세요:'))
greencount=int(input('초록색 접시의 개수를 입력하세요:'))
r=red*redcount
y=yellow*yellowcount
b=blue*bluecount
g=green*greencount
print(f'=====회전 초밥 영수증===== \n 접시 \t단가\t개수\t합계\n빨간색\t1,000\t{redcount}\t{yellowcount*red}\n노란색\t2,000\t{yellowcount}\t{yellowcount*yellow}\n파란색\t3,000\t{bluecount}\t{bluecount*blue}\n초록색\t4,000\t{greencount}\t{greencount*green}\n\ttotal\t{r+y+b+g}\n=======================')
# Out:
# 빨간색 접시의 개수를 입력하세요3
# 노랑색 접시의 개수를 입력하세요4
# 파란색 접시의 개수를 입력하세요5
# 초록색 접시의 개수를 입력하세요6
# =====회전 초밥 영수증=====
#  접시 	단가	개수	합계
# 빨간색	1,000	3	4000
# 노란색	2,000	4	8000
# 파란색	3,000	5	15000
# 초록색	4,000	6	24000
# 	total	50000
# ...
