# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOIHYUNJUN10/10720/blob/main/20260903.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('재미있는 프로그래밍')
print(3+7)
print('3+7')
print(10,20,30,'정보','프로그래밍')
# Out:
# 재미있는 프로그래밍
# 10
# 3+7
# 10 20 30 정보 프로그래밍

# %%
print('한양과학기술고등학교 1학년 최현준')
print('bmi지수','=',67/(174*174)*10000)
# Out:
# 한양과학기술고등학교 1학년 최현준
# bmi지수 = 22.12973972783723

# %%
a=20
b=50
print(f'현재 온도는 {a}도, 습도는 {b}% 입니다.')
# Out:
# 현재 온도는 20도, 습도는 50% 입니다.

# %%
c=90
d=3.141592
print(f'직각은 {c}도, 원주율은 {d:0.2f}입니다.')
# Out:
# 직각은 90도, 원주율은 3.14입니다.
