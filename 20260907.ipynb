# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOIHYUNJUN10/10720/blob/main/20260907.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
from datetime import datetime,date,time

# %%
print('<디데이(D-day) 프로그램>')
print()
year = int(input('연도를 입력하세요:'))
month = int(input('월을 입력하세요:'))
day = int(input('일을 입력하세요:'))
dt4 = date(year,month,day)
today =
date.today()
dday = (dt4 - today).days
print(f'{year}년 {month}월 {day}일은 {dday}일 남았습니다.')
# Out:
# <디데이(D-day) 프로그램>
#
# 연도를 입력하세요:2026
# 월을 입력하세요:10
# 일을 입력하세요:19
# 2026년 10월 19일은 42일 남았습니다.

# %%
print('<회전 초밥 가격 계산기>')
print()
blue=int(input('파란색 접시의 개수를 입력하세세요.'))
